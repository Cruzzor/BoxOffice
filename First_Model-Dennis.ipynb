# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error

# %%
data = pd.read_csv('../data/train.csv')
flo_genre = pd.read_csv('../data/flo_genre_feature.csv').drop('Unnamed: 0', axis=1)
flo_age = pd.read_csv('../data/flo_age_feature.csv').drop('Unnamed: 0', axis=1)
marcel_keywords = pd.read_csv('../data/marcel_features.csv').drop('Unnamed: 0', axis=1)

data['popularity'] = np.log1p(data.popularity)
data = data.merge(flo_genre, on=['id'], how='left').merge(marcel_keywords, on=['id'], how='left').merge(flo_age, on=['id'], how='left')

data.runtime = data.runtime.fillna(np.mean(data.runtime))

# %%
features = list(flo_genre.columns) + ['popularity', 'budget', 'has_top_keyword']
features.remove('id')

features_df = data[features]
target = data.revenue

X_train, X_test, y_train, y_test = train_test_split(features_df, target, test_size=0.33, random_state=42)

reg = LinearRegression()
reg.fit(X_train, np.log1p(y_train))
y_pred = np.exp(reg.predict(X_test)) - 1
np.sqrt(mean_squared_log_error(y_test, y_pred))
# Out:
# 2.209947521255649

# %%
features2 = features + ['runtime']

features_df = data[features2]
target = data.revenue
X_train, X_test, y_train, y_test = train_test_split(features_df, target, test_size=0.33, random_state=42)

reg = LinearRegression()
reg.fit(X_train, np.log1p(y_train))
y_pred = np.exp(reg.predict(X_test)) - 1
np.sqrt(mean_squared_log_error(y_test, y_pred))
# Out:
# 2.2130484152059466

# %%
features3 = features + ['age']

features_df = data[features3]
target = data.revenue
X_train, X_test, y_train, y_test = train_test_split(features_df, target, test_size=0.33, random_state=42)

reg = LinearRegression()
reg.fit(X_train, np.log1p(y_train))
y_pred = np.exp(reg.predict(X_test)) - 1
np.sqrt(mean_squared_log_error(y_test, y_pred))
# Out:
# 2.2278545800207255

# %%
data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity    ...      \
# 0  When Lou, who has become the "father of the In...    2.024905    ...
# 1  Mia Thermopolis is now a college graduate and ...    2.224504    ...
# 2  Under the direction of a ruthless instructor, ...    4.178992    ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    1.429099    ...
# 4  Marine Boy is the story of a former national s...    0.764570    ...
#
#   Fantasy Romance History  Crime    War TV Movie Thriller Foreign  \
# 0   False   False   False  False  False    False    False   False
# 1   False    True   False  False  False    False    False   False
# 2   False   False   False  False  False    False    False   False
# 3   False   False   False  False  False    False     True   False
# 4   False   False   False  False  False    False     True   False
#
#   has_top_keyword        age
# 0            True   4.063014
# 1           False  14.610959
# 2           False   4.427397
# 3           False   7.016438
# 4           False  10.106849
#
# [5 rows x 45 columns]

# %%
data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    2.024905
# 1  Mia Thermopolis is now a college graduate and ...    2.224504
# 2  Under the direction of a ruthless instructor, ...    4.178992
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    1.429099
# 4  Marine Boy is the story of a former national s...    0.764570
#
#            ...          Romance History  Crime    War  TV Movie Thriller  \
# 0          ...            False   False  False  False     False    False
# 1          ...             True   False  False  False     False    False
# 2          ...            False   False  False  False     False    False
# 3          ...            False   False  False  False     False     True
# 4          ...            False   False  False  False     False     True
#
#   Foreign has_top_keyword        age original_title_length
# 0   False            True   4.063014                    22
# 1   False           False  14.610959                    40
# 2   False           False   4.427397                     8
# 3   False           False   7.016438                     7
# 4   False           False  10.106849                     4
#
# [5 rows x 46 columns]

# %%
features4 = features + ['original_title_length']

features_df = data[features4]
target = data.revenue
X_train, X_test, y_train, y_test = train_test_split(features_df, target, test_size=0.33, random_state=42)

reg = LinearRegression()
reg.fit(X_train, np.log1p(y_train))
y_pred = np.exp(reg.predict(X_test)) - 1
np.sqrt(mean_squared_log_error(y_test, y_pred))
# Out:
# 2.210585626253336
